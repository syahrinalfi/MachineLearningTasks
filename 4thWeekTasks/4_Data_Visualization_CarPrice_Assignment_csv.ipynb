# %% [markdown]
# <a href="https://colab.research.google.com/github/syahrinalfi/MachineLearningTasks/blob/main/4thWeekTasks/4_Data_Visualization_CarPrice_Assignment_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * Nama : Muhammad Alfi Syahrin
# * NIM : 1103213144
# * Lecture : 4
# * Model : Visualisasi Data
# * Dataset : CarPrice_Assignment.csv (https://github.com/pranavhaldar/Car-Price_Linear-Regression-Assignment/blob/master/CarPrice_Assignment.csv)

# %%
from google.colab import drive
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Mount Drive
drive.mount('/content/drive')

# Impor File CSV
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Machine Learning/Minggu 4/CarPrice_Assignment.csv")
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Feature Statistic

# %% [markdown]
# Prompt ChatGPT = "Tampilkan statistik fitur diamonds.csv"

# %%
# Menampilkan Statistik Fitur
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %% [markdown]
# # Box Plot

# %% [markdown]
# Prompt ChatGPT = "Tampilkan informasi data diamonds.csv"

# %%
# Menampilkan informasi dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %% [markdown]
# Prompt ChatGPT = "Tampilkan fitur numerik dalam bentuk boxplot secara terpisah"

# %%
# Memilih hanya fitur numerik
numerical_features = df.select_dtypes(include=['int64', 'float64']).columns.tolist()

# Membuat boxplot untuk setiap fitur numerik
for feature in numerical_features:
    plt.figure(figsize=(8, 6))
    sns.boxplot(x=df[feature])
    plt.title(f'Boxplot of {feature}')
    plt.show()

# %% [markdown]
# # Scatter Plot

# %% [markdown]
# Prompt ChatGPT = "Tampilkan fitur numerik dalam bentuk scatter plot"

# %%
# Membuat scatter plot untuk setiap pasangan fitur numerik
sns.set(style="ticks")
sns.pairplot(df[numerical_features])
plt.show()

# %% [markdown]
# # Distribution Plot

# %% [markdown]
# Prompt ChatGPT = "Tampilkan fitur numerik dalam bentuk distribution plot"

# %%
# Membuat distribusi plot untuk setiap fitur numerik
for feature in numerical_features:
    plt.figure(figsize=(8, 6))
    sns.histplot(df[feature], kde=True, bins=30)
    plt.title(f'Distribution Plot of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# # Violin Plot

# %% [markdown]
# Prompt ChatGPT = "Tampilkan fitur numerik dalam bentuk violin plot"

# %%
# Membuat violin plot untuk setiap fitur numerik
for feature in numerical_features:
    plt.figure(figsize=(8, 6))
    sns.violinplot(x=df[feature], inner='quartile')
    plt.title(f'Violin Plot of {feature}')
    plt.xlabel(feature)
    plt.show()

# %% [markdown]
# # Heatmap

# %% [markdown]
# Prompt ChatGPT = "Tampilkan heatmap untuk fitur numerik"

# %%
# Menghitung korelasi antar fitur numerik
correlation_matrix = df[numerical_features].corr()

# Membuat heatmap untuk korelasi
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Heatmap of Numerical Features Correlation')
plt.show()
